# %% [markdown]
# # Part 1 -- SQL Queries

# %%
import os
import sqlite3

# %%
con = sqlite3.connect(os.path.join('data', 'combined_data.db'))
cur = con.cursor()

# %%
res = cur.execute("""
    SELECT * FROM sqlite_master
""")

for c in cur.fetchall():
    print(c)
# Out:
# ('table', 'CompanyClassification', 'CompanyClassification', 2, 'CREATE TABLE "CompanyClassification" (\n"Category" TEXT,\n  "Website" TEXT,\n  "CompanyName" TEXT,\n  "homepage_text" TEXT,\n  "h1" TEXT,\n  "h2" TEXT,\n  "h3" TEXT,\n  "nav_link_text" TEXT,\n  "meta_keywords" TEXT,\n  "meta_description" TEXT\n)')
# ('table', 'CompanyDataset', 'CompanyDataset', 110723, 'CREATE TABLE "CompanyDataset" (\n"Unnamed: 0" INTEGER,\n  "CompanyName" TEXT,\n  "Website" TEXT,\n  "year founded" REAL,\n  "industry" TEXT,\n  "size range" TEXT,\n  "locality" TEXT,\n  "country" TEXT,\n  "linkedin url" TEXT,\n  "current employee estimate" INTEGER,\n  "total employee estimate" INTEGER\n)')

# %% [markdown]
# ## Query 1

# %%
query_1 = """
    SELECT industry, AVG(`current employee estimate`) AS average_employee_estimate 
    FROM CompanyDataset 
    WHERE `year founded` > 2002 AND `current employee estimate` > 10 
    GROUP BY industry 
    ORDER BY average_employee_estimate DESC 
    LIMIT 10;
"""

# %%
cur.execute(query_1)

for c in cur.fetchall():
    print(c)
# Out:
# ('tobacco', 775.8461538461538)
# ('government administration', 176.92786293958522)
# ('supermarkets', 153.74074074074073)
# ('banking', 148.2915951972556)
# ('paper & forest products', 147.56410256410257)
# ('judiciary', 127.27868852459017)
# ('legislative office', 126.375)
# ('aviation & aerospace', 122.46805555555555)
# ('mining & metals', 120.5695652173913)
# ('semiconductors', 112.05504587155963)

# %%
cur.execute(f"""
    EXPLAIN QUERY PLAN {query_1}
""")

for c in cur.fetchall():
    print(c)
# Out:
# (8, 0, 0, 'SCAN CompanyDataset')
# (15, 0, 0, 'USE TEMP B-TREE FOR GROUP BY')
# (57, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')

# %% [markdown]
# ### Create an index on a numeric column which will also be used in following queries

# %%
cur.execute("""
    CREATE INDEX employees ON CompanyDataset (`current employee estimate`);
""")

# %%
cur.execute(f"""
    EXPLAIN QUERY PLAN {query_1}
""")

for c in cur.fetchall():
    print(c)
# Out:
# (9, 0, 0, 'SEARCH CompanyDataset USING INDEX employees (current employee estimate>?)')
# (16, 0, 0, 'USE TEMP B-TREE FOR GROUP BY')
# (58, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')

# %% [markdown]
# ## Query 2

# %%
query_2 = """
    SELECT DISTINCT d.CompanyName
    FROM CompanyDataset d, CompanyClassification c
    WHERE d.CompanyName = c.CompanyName AND 
          industry LIKE "%Technology%" AND 
          d.`current employee estimate` < 100 AND 
          TRIM(homepage_text, ' ') IS NULL
    ORDER BY d.CompanyName;
"""

# %%
cur.execute(query_2)

for c in cur.fetchall():
    print(c)
# Out:
# ('anadys pharmaceuticals',)
# ('blubridge solutions inc',)
# ('boomzip cloud solutions',)
# ('ccw web building solutions (closed)',)
# ('cdn tech solutions',)
# ('cloud my office',)
# ('compudev solutions',)
# ('dimidium solutions inc.',)
# ('elogitech solutions',)
# ('expand learning solutions',)
# ('fortech software inc.',)
# ('global commerce & information, inc. (global ci)',)
# ('information services usa',)
# ('itrend business solutions cc',)
# ('kineta software',)
# ('kuplasolutions',)
# ('microtop computer co. llc',)
# ('midwest design computers',)
# ('perceptronix medical inc.',)
# ('risen solutions',)
# ('shock therapeutics biotechnologies',)
# ('smartphone software inc.',)
# ('star computers',)
# ('targeted sales solutions',)
# ('tech4sys software solutions',)
# ('techsys business solutions',)
# ('tenderfield construction software',)
# ('w3cloud llc',)
# ('wireless 1 apps inc.',)

# %%
cur.execute(f"""
    EXPLAIN QUERY PLAN {query_2}
""")

for c in cur.fetchall():
    print(c)
# Out:
# (9, 0, 0, 'SEARCH d USING INDEX employees (current employee estimate<?)')
# (30, 0, 0, 'SEARCH c USING AUTOMATIC PARTIAL COVERING INDEX (CompanyName=?)')
# (38, 0, 0, 'USE TEMP B-TREE FOR DISTINCT')

# %% [markdown]
# ## Query 3

# %%
query_3 = """
    SELECT DISTINCT country, CompanyName, `total employee estimate`, rank_id
    FROM ( 
        SELECT country, CompanyName, `total employee estimate`, 
            ROW_NUMBER() OVER (PARTITION BY country ORDER BY `total employee estimate` DESC) AS rank_id 
        FROM CompanyDataset 
        WHERE TRIM(country, ' ') IS NOT NULL
    ) AS ranks
    WHERE rank_id <= 5
    ORDER BY country, rank_id;
"""

# %%
cur.execute(query_3)

for c in cur.fetchall():
    print(c)
# Out:
# ('afghanistan', 'roshan', 986, 1)
# ('afghanistan', 'awcc', 823, 2)
# ('afghanistan', 'etisalat afghanistan', 818, 3)
# ('afghanistan', 'ministry of agriculture, irrigation and livestock', 508, 4)
# ('afghanistan', 'mtn afghanistan', 423, 5)
# ('albania', 'albtelecom albania', 892, 1)
# ('albania', 'raiffeisen bank albania', 779, 2)
# ('albania', 'telekom albania', 671, 3)
# ('albania', 'intesa sanpaolo bank albania', 447, 4)
# ('albania', 'national food authority', 399, 5)
# ('algeria', 'sonatrach', 17062, 1)
# ('algeria', 'algerie telecom', 3017, 2)
# ('algeria', 'ooredoo algérie', 2318, 3)
# ('algeria', 'groupe cevital', 2298, 4)
# ('algeria', 'naftal spa', 1879, 5)
# ('american samoa', 'american samoa government', 268, 1)
# ('american samoa', 'blue sky communications', 96, 2)
# ('american samoa', 'american samoa community college', 32, 3)
# ('american samoa', 'genexy company limited', 6, 4)
# ('american samoa', 'rda law firm', 3, 5)
# ('andorra', 'crèdit andorrà', 472, 1)
# ('andorra', 'banca privada andorra', 444, 2)
# ('andorra', "govern d'andorra", 350, 3)
# ('andorra', 'morabanc', 227, 4)
# ('andorra', 'andorra telecom', 196, 5)
# ('angola', 'unitel', 1641, 1)
# ('angola', 'bfa', 869, 2)
# ('angola', 'angola lng', 817, 3)
# ('angola', 'ucall angola', 517, 4)
# ('angola', 'bai - banco angolano de investimentos, s.a.', 487, 5)
# ('anguilla', 'government of anguilla', 124, 1)
# ('anguilla', 'anguilla electricity company limited (anglec)', 30, 2)
# ('anguilla', 'rally trade', 26, 3)
# ('anguilla', 'keithley lake & associates', 18, 4)
# ('anguilla', 'department of youth and culture (anguilla)', 6, 5)
# ('antigua and barbuda', 'kpmg eastern caribbean', 11, 1)
# ('antigua and barbuda', 'caribbean developments (antigua) ltd.', 10, 2)
# ('antigua and barbuda', 'curtain bluff resort', 7, 3)
# ('antigua and barbuda', 'directorate of gender affairs', 5, 4)
# ('antigua and barbuda', 'absolute poker', 5, 5)
# ('argentina', 'gobierno de la ciudad de buenos aires', 11837, 1)
# ('argentina', 'universidad de buenos aires', 10934, 2)
# ('argentina', 'ypf s.a.', 10875, 3)
# ('argentina', 'globant', 9689, 4)
# ('argentina', 'estudio juridico', 7824, 5)
# ('armenia', 'yerevan state university', 963, 1)
# ('armenia', 'central bank of armenia', 650, 2)
# ('armenia', 'orange armenia', 581, 3)
# ('armenia', 'american university of armenia', 502, 4)
# ('armenia', 'ucom llc', 499, 5)
# ('aruba', 'setar nv', 222, 1)
# ('aruba', 'aruba bank n.v.', 198, 2)
# ('aruba', 'aruba tourism authority', 179, 3)
# ('aruba', 'caribbean mercantile bank n.v.', 113, 4)
# ('aruba', 'sf', 97, 5)
# ('australia', 'anz', 62120, 1)
# ('australia', 'fujitsu', 54138, 2)
# ('australia', 'telstra', 49199, 3)
# ('australia', 'commonwealth bank', 43277, 4)
# ('australia', 'national australia bank', 41910, 5)
# ('austria', 'red bull', 28990, 1)
# ('austria', 'omv', 8767, 2)
# ('austria', 'andritz', 8255, 3)
# ('austria', 'benteler automotive', 7256, 4)
# ('austria', 'strabag', 6409, 5)
# ('azerbaijan', 'baku 2015 european games operation committee', 1833, 1)
# ('azerbaijan', 'state oil company of the republic of azerbaijan (socar)', 1712, 2)
# ('azerbaijan', 'azercell', 1178, 3)
# ('azerbaijan', 'azersun holding', 1162, 4)
# ('azerbaijan', 'bakcell', 867, 5)
# ('bahamas', 'bahamas telecommunications company ltd.', 701, 1)
# ('bahamas', 'baha mar', 588, 2)
# ('bahamas', 'akelius residential', 427, 3)
# ('bahamas', 'doctors hospital', 382, 4)
# ('bahamas', 'unique vacations, ltd.', 349, 5)
# ('bahrain', 'gulf air', 4054, 1)
# ('bahrain', 'bank abc (arab banking corporation b.s.c)', 1791, 2)
# ('bahrain', 'gulf international bank', 1468, 3)
# ('bahrain', 'jawad business group', 1456, 4)
# ('bahrain', 'batelco', 1286, 5)
# ('bangladesh', 'grameenphone ltd', 7819, 1)
# ('bangladesh', 'banglalink', 3644, 2)
# ('bangladesh', 'robi axiata limited', 3543, 3)
# ('bangladesh', 'brac', 2983, 4)
# ('bangladesh', 'pran-rfl group', 2334, 5)
# ('barbados', 'kpmg in barbados', 116, 1)
# ('barbados', 'lex caribbean', 111, 2)
# ('barbados', 'barbados tourism authority', 95, 3)
# ('barbados', 'seaco', 93, 4)
# ('barbados', 'terra caribbean', 86, 5)
# ('belarus', 'iba group', 1200, 1)
# ('belarus', 'incom', 1099, 2)
# ('belarus', 'unitary enterprise velcom (velcom & privet)', 744, 3)
# ('belarus', 'issoft', 520, 4)
# ('belarus', 'andersen', 388, 5)
# ('belgium', 'european commission', 42726, 1)
# ('belgium', 'anheuser-busch inbev', 26419, 2)
# ('belgium', 'solvay', 24215, 3)
# ('belgium', 'bnp paribas fortis', 21640, 4)
# ('belgium', 'european parliament', 20559, 5)
# ('belize', 'telemedia', 523, 1)
# ('belize', 'university of belize', 412, 2)
# ('belize', 'bowen & bowen, ltd.', 67, 3)
# ('belize', 'hillside health care international', 58, 4)
# ('belize', 'beltraide', 55, 5)
# ('benin', 'eurial', 592, 1)
# ('benin', 'direction générale du trésor et de la comptabilité publique', 459, 2)
# ('benin', 'mtn benin', 424, 3)
# ('benin', "l'école de design nantes atlantique", 378, 4)
# ('benin', 'vif', 233, 5)
# ('bermuda', 'xl catlin', 8792, 1)
# ('bermuda', 'lazard', 6355, 2)
# ('bermuda', 'signet', 3929, 3)
# ('bermuda', 'hiscox', 3171, 4)
# ('bermuda', 'wilson sons', 2762, 5)
# ('bhutan', 'tourism', 826, 1)
# ('bhutan', 'druk green', 124, 2)
# ('bhutan', 'druk holding & investments', 78, 3)
# ('bhutan', 'tourism council of bhutan', 54, 4)
# ('bhutan', 'drukair corporation ltd.', 50, 5)
# ('bolivia', 'ypfb corporacion', 744, 1)
# ('bolivia', 'entel bolivia', 693, 2)
# ('bolivia', 'nuevatel', 641, 3)
# ('bolivia', 'ypfb transporte s.a.', 509, 4)
# ('bolivia', 'gobierno autónomo departamental de santa cruz', 450, 5)
# ('bosnia and herzegovina', 'bh telecom d.d. sarajevo', 532, 1)
# ('bosnia and herzegovina', 'raiffeisen bank dd bih', 465, 2)
# ('bosnia and herzegovina', 'energoinvest', 379, 3)
# ('bosnia and herzegovina', 'office of the high representative', 320, 4)
# ('bosnia and herzegovina', 'telekom srpske', 300, 5)
# ('botswana', 'bancabc', 937, 1)
# ('botswana', 'water utilities corporation', 828, 2)
# ('botswana', 'botswana telecommunications corporation (btc)', 774, 3)
# ('botswana', 'first national bank of botswana limited', 747, 4)
# ('botswana', 'mascom wireless', 380, 5)
# ('brazil', 'itaú unibanco', 53270, 1)
# ('brazil', 'petrobras', 51919, 2)
# ('brazil', 'vale', 44516, 3)
# ('brazil', 'bradesco', 39194, 4)
# ('brazil', 'caixa economica federal', 32283, 5)
# ('british virgin islands', 'bahia specialty cellulose ( sateri iternational group )', 569, 1)
# ('british virgin islands', 'iforex', 485, 2)
# ('british virgin islands', 'latcapital solutions', 459, 3)
# ('british virgin islands', 'harneys', 439, 4)
# ('british virgin islands', 'ek success', 314, 5)
# ('brunei', 'kfc (b) sdn bhd', 1664, 1)
# ('brunei', 'royal brunei airlines', 795, 2)
# ('brunei', 'dst', 332, 3)
# ('brunei', 'ubd', 318, 4)
# ('brunei', 'petrokon utama sdn bhd', 300, 5)
# ('bulgaria', 'mobiltel', 2937, 1)
# ('bulgaria', 'vivacom', 2487, 2)
# ('bulgaria', 'unicredit bulbank', 2205, 3)
# ('bulgaria', 'telus international europe', 1355, 4)
# ('bulgaria', 'raiffeisen bank - bulgaria', 1298, 5)
# ('burkina faso', 'onatel', 375, 1)
# ('burkina faso', "2ie - institut international d'ingénierie de l'eau et de l'environnement", 309, 2)
# ('burkina faso', 'initiatives conseil international', 131, 3)
# ('burkina faso', 'international school of ouagadougou', 94, 4)
# ('burkina faso', 'softnet burkina', 80, 5)
# ('burundi', 'smart east africa', 88, 1)
# ('burundi', 'brasseries et limonaderies du burundi brarudi s.a.', 49, 2)
# ('burundi', 'burundi backbone systems', 28, 3)
# ('burundi', '-independent consultant-', 17, 4)
# ('burundi', 'scad', 12, 5)
# ('cambodia', 'nagaworld', 607, 1)
# ('cambodia', 'acleda bank', 598, 2)
# ('cambodia', 'smart axiata', 548, 3)
# ('cambodia', 'camgsm company limited (mobitel)', 455, 4)
# ('cambodia', 'ministry of commerce', 445, 5)
# ('cameroon', 'mtn cameroon', 1502, 1)
# ('cameroon', 'orange cameroun', 1154, 2)
# ('cameroon', 'ocean park corporation', 652, 3)
# ('cameroon', 'ccaa', 648, 4)
# ('cameroon', 'camair-co', 346, 5)
# ('canada', 'td', 93645, 1)
# ('canada', 'cgi', 74922, 2)
# ('canada', 'scotiabank', 65086, 3)
# ('canada', 'rbc', 60194, 4)
# ('canada', 'nortel', 52349, 5)
# ('cape verde', 'nosi - nucleo operacional da sociedade de informacao', 141, 1)
# ('cape verde', 'tacv - cape verde airlines', 83, 2)
# ('cape verde', 'language link', 74, 3)
# ('cape verde', 'enacol', 61, 4)
# ('cape verde', 'dgci- direcção geral das contribuições e impostos', 54, 5)
# ('caribbean netherlands', 'stinapa bonaire', 36, 1)
# ('caribbean netherlands', 'telefonia bonairiano n.v.', 21, 2)
# ('caribbean netherlands', 'water- en energiebedrijf bonaire n.v.', 17, 3)
# ('caribbean netherlands', 'openbaar lichaam bonaire', 13, 4)
# ('caribbean netherlands', 'dutch caribbean nature alliance', 12, 5)
# ('cayman islands', 'ooredoo qatar', 2672, 1)
# ('cayman islands', 'maples and calder', 1111, 2)
# ('cayman islands', 'minera chinalco perú s.a.', 935, 3)
# ('cayman islands', 'theatre', 922, 4)
# ('cayman islands', 'walkers', 873, 5)
# ('central african republic', 'telecel centrafrique sa', 25, 1)
# ('central african republic', 'millenium telecom centrafrique s.a.', 8, 2)
# ('central african republic', 'sucaf rca', 8, 3)
# ('central african republic', 'societe sefca', 4, 4)
# ('chad', 'compagnie sucrière du tchad (cst)', 31, 1)
# ('chad', 'global logistics services limited (gls)', 11, 2)
# ('chad', 'hotel la mirande tchad', 6, 3)
# ('chad', 'web tchad', 6, 4)
# ('chad', 'societe des telecommunications du tchad', 5, 5)
# ('chile', 'cencosud s.a.', 16697, 1)
# ('chile', 'sonda', 15488, 2)
# ('chile', 'lan airlines', 13750, 3)
# ('chile', 'pontificia universidad católica de chile', 13520, 4)
# ('chile', 'entel', 11411, 5)
# ('china', 'huawei technologies', 113434, 1)
# ('china', 'tencent', 42617, 2)
# ('china', 'zte', 23550, 3)
# ('china', 'bank of china', 16873, 4)
# ('china', 'baidu inc.', 13458, 5)
# ('colombia', 'sena', 18739, 1)
# ('colombia', 'universidad nacional de colombia', 13318, 2)
# ('colombia', 'universidad de los andes', 9491, 3)
# ('colombia', 'university of puerto rico', 8242, 4)
# ('colombia', 'ecopetrol', 8134, 5)
# ('comoros', 'bcg ltd.', 13, 1)
# ('comoros', 'dahari', 8, 2)
# ('comoros', 'banque federale de commerce', 6, 3)
# ('comoros', 'ecdd comores', 6, 4)
# ('comoros', 'star account', 4, 5)
# ('cook islands', 'pacific resort hotel group - cook islands', 108, 1)
# ('cook islands', 'cook island networking entertainment & multimedia associates (c.i.n.e.m.a.)', 68, 2)
# ('cook islands', 'the rarotongan beach resort & spa', 66, 3)
# ('cook islands', 'telecom cook islands', 63, 4)
# ('cook islands', 'cook islands ministry of finance and economic management', 42, 5)
# ('costa rica', 'universidad de costa rica', 5023, 1)
# ('costa rica', 'banco nacional', 1971, 2)
# ('costa rica', 'una', 1730, 3)
# ('costa rica', 'poder judicial costa rica', 1100, 4)
# ('costa rica', 'gbm corporation', 1098, 5)
# ('croatia', 'hrvatski telekom', 2969, 1)
# ('croatia', 'ina - industrija nafte, d.d.', 2561, 2)
# ('croatia', 'pliva', 2112, 3)
# ('croatia', 'vipnet d.o.o.', 1947, 4)
# ('croatia', 'zagrebačka banka', 1712, 5)
# ('cuba', 'universidad de la habana', 1052, 1)
# ('cuba', 'uclv', 708, 2)
# ('cuba', 'melia hotels international cuba', 407, 3)
# ('cuba', 'datys', 200, 4)
# ('cuba', 'joven club de computación y electrónica', 192, 5)
# ('curaçao', 'bluewater energy services', 1652, 1)
# ('curaçao', 'q8 kpnwe', 715, 2)
# ('curaçao', 'keppel verolme', 434, 3)
# ('curaçao', 'business lease', 404, 4)
# ('curaçao', 'seatrade', 396, 5)
# ('cyprus', 'wargaming.net', 3443, 1)
# ('cyprus', 'bank of cyprus', 2962, 2)
# ('cyprus', 'bernhard schulte shipmanagement', 2608, 3)
# ('cyprus', 'university of cyprus', 1927, 4)
# ('cyprus', 'emu', 1910, 5)
# ('czechia', 'private', 21432, 1)
# ('czechia', 'geen', 11722, 2)
# ('czechia', 'česká spořitelna, a.s.', 6596, 3)
# ('czechia', 'csob', 4837, 4)
# ('czechia', 'o2 czech republic', 4707, 5)
# ('côte d’ivoire', "orange côte d'ivoire", 1029, 1)
# ('côte d’ivoire', 'société ivoirienne de banque', 343, 2)
# ('côte d’ivoire', "jumia côte d'ivoire", 253, 3)
# ('côte d’ivoire', 'groupe sifca', 230, 4)
# ('côte d’ivoire', 'sania cie', 219, 5)
# ('democratic republic of the congo', 'kamoto copper company sarl', 386, 1)
# ('democratic republic of the congo', 'rawbank', 380, 2)
# ('democratic republic of the congo', 'vodacom congo (rdc) s.a', 323, 3)
# ('democratic republic of the congo', 'trust merchant bank', 278, 4)
# ('democratic republic of the congo', 'tenke fungurume mining s.a.r.l.', 271, 5)
# ('denmark', 'danske bank', 22372, 1)
# ('denmark', 'maersk line', 22012, 2)
# ('denmark', 'vestas', 18230, 3)
# ('denmark', 'aarhus university', 16556, 4)
# ('denmark', 'ramboll', 16307, 5)
# ('djibouti', 'lutheran world federation', 173, 1)
# ('djibouti', 'sheraton hotel djibouti', 43, 2)
# ('djibouti', 'port of djibouti', 41, 3)
# ('djibouti', 'dahabshil bank international', 32, 4)
# ('djibouti', 'massida logistics', 31, 5)
# ('dominica', 'ross university school of medicine', 985, 1)
# ('dominica', 'dominica electricity services ltd', 23, 2)
# ('dominica', 'jungle bay dominica', 14, 3)
# ('dominica', 'evenforex.com', 12, 4)
# ('dominica', 'invest dominica authority', 11, 5)
# ('dominican republic', 'banco popular dominicano', 2311, 1)
# ('dominican republic', 'claro rd', 2093, 2)
# ('dominican republic', 'ministerio de educacion de la republica dominican', 1350, 3)
# ('dominican republic', 'banreservas', 1231, 4)
# ('dominican republic', 'orange dominicana', 1146, 5)
# ('ecuador', 'banco pichincha', 2170, 1)
# ('ecuador', 'banco del estado', 2009, 2)
# ('ecuador', 'pronaca', 1691, 3)
# ('ecuador', 'universidad san francisco de quito', 1619, 4)
# ('ecuador', 'universidad central del ecuador', 1567, 5)
# ('egypt', 'mobinil', 7449, 1)
# ('egypt', 'cairo university', 6015, 2)
# ('egypt', 'american university in cairo', 5494, 3)
# ('egypt', 'cib egypt', 4866, 4)
# ('egypt', 'orascom construction industries (oci)', 4844, 5)
# ('el salvador', 'taca', 1794, 1)
# ('el salvador', 'almacenes siman', 1053, 2)
# ('el salvador', 'banco agricola', 1011, 3)
# ('el salvador', 'universidad de el salvador', 978, 4)
# ('el salvador', 'grupo roble', 522, 5)
# ('equatorial guinea', 'ministerio de cultura', 1293, 1)
# ('equatorial guinea', 'ministerio de transportes y telecomunicaciones', 1101, 2)
# ('equatorial guinea', 'somagec ge', 265, 3)
# ('equatorial guinea', 'centro medico la paz', 68, 4)
# ('equatorial guinea', 'banco nacional de guinea ecuatorial', 36, 5)
# ('eritrea', 'zara mining share company', 60, 1)
# ('eritrea', 'orange asmara it solutions', 4, 2)
# ('eritrea', 'unilink s.c.', 2, 3)
# ('eritrea', 'asmara rental', 1, 4)
# ('estonia', 'hotmail', 2790, 1)
# ('estonia', 'university of tartu', 2282, 2)
# ('estonia', 'infosys ltd.', 2045, 3)
# ('estonia', 'good deed foundation', 1558, 4)
# ('estonia', 'tallinn university of technology', 1491, 5)
# ('ethiopia', 'ethiopian airlines', 3329, 1)
# ('ethiopia', 'addis ababa university', 2481, 2)
# ('ethiopia', 'mekelle university', 1337, 3)
# ('ethiopia', 'african union commission, addis ababa', 1335, 4)
# ('ethiopia', 'united nations economic commission for africa', 924, 5)
# ('faroe islands', 'eik bank', 227, 1)
# ('faroe islands', 'p/f smyril line', 154, 2)
# ('faroe islands', 'faroese telecom', 141, 3)
# ('faroe islands', 'ministry of fisheries', 128, 4)
# ('faroe islands', 'landsverk', 79, 5)
# ('fiji', 'university of the south pacific', 2586, 1)
# ('fiji', 'nesma & partners', 2450, 2)
# ('fiji', 'saad specialist hospital', 2172, 3)
# ('fiji', 'zamil steel', 1939, 4)
# ('fiji', 'saudi business machines - sbm', 1663, 5)
# ('finland', 'nokia', 251795, 1)
# ('finland', 'tieto', 21221, 2)
# ('finland', 'kone', 16946, 3)
# ('finland', 'metso', 14891, 4)
# ('finland', 'wärtsilä', 11958, 5)
# ('france', 'capgemini', 203525, 1)
# ('france', "l'oréal", 107296, 2)
# ('france', 'bnp paribas', 101571, 3)
# ('france', 'education nationale', 101083, 4)
# ('france', 'sanofi', 99940, 5)
# ('french guiana', 'rectorat de la guyane', 297, 1)
# ('french guiana', 'atlas voyages', 226, 2)
# ('french guiana', 'k2 design', 21, 3)
# ('french guiana', 'gestimmo', 17, 4)
# ('french guiana', 'rexma', 16, 5)
# ('french polynesia', 'le meridien', 1374, 1)
# ('french polynesia', 'air tahiti nui', 424, 2)
# ('french polynesia', 'la vie en bleu', 419, 3)
# ('french polynesia', 'tahiti tourisme', 108, 4)
# ('french polynesia', 'tahiti nui travel', 106, 5)
# ('gabon', 'heliatec', 140, 1)
# ('gabon', 'agence nationale des infrastructures numériques et des fréquences (aninf)', 97, 2)
# ('gabon', 'gabon telecom s.a.', 97, 3)
# ('gabon', 'perenco gabon sa', 85, 4)
# ('gabon', 'gabon oil company (goc)', 79, 5)
# ('gambia', 'university of the gambia', 333, 1)
# ('gambia', 'coco ocean resort & spa', 77, 2)
# ('gambia', 'pristine consulting (gambia)', 40, 3)
# ('gambia', 'institute for human rights and development in africa (ihrda)', 29, 4)
# ('gambia', 'mfh group', 27, 5)
# ('georgia', 'tbc bank', 2000, 1)
# ('georgia', 'bank of georgia', 1770, 2)
# ('georgia', 'ilia state university', 1058, 3)
# ('georgia', 'bank republic societe generale group', 954, 4)
# ('georgia', 'ivane javakhishvili tbilisi state university', 877, 5)
# ('germany', 'siemens', 240528, 1)
# ('germany', 'deutsche bank', 118832, 2)
# ('germany', 'dhl', 111977, 3)
# ('germany', 'basf', 64209, 4)
# ('germany', 'continental', 53657, 5)
# ('ghana', 'university of ghana legon', 2178, 1)
# ('ghana', 'kwame nkrumah university of science & technology, kumasi', 2083, 2)
# ('ghana', 'komfo anokye teaching hospital', 1002, 3)
# ('ghana', 'gcb bank limited', 854, 4)
# ('ghana', 'mantrac ghana limited', 772, 5)
# ('gibraltar', 'bwin.party digital entertainment', 3067, 1)
# ('gibraltar', 'betvictor', 856, 2)
# ('gibraltar', 'mansion', 616, 3)
# ('gibraltar', 'stan james', 380, 4)
# ('gibraltar', 'pokerstrategy.com', 332, 5)
# ('greece', 'consolidated contractors international company', 13267, 1)
# ('greece', 'piraeus bank', 6791, 2)
# ('greece', 'national bank of greece', 6274, 3)
# ('greece', 'eurobank (gre)', 5374, 4)
# ('greece', 'alpha bank', 5068, 5)
# ('greenland', 'royal greenland', 928, 1)
# ('greenland', 'naalakkersuisut - grønlands selvstyre', 564, 2)
# ('greenland', 'air greenland', 542, 3)
# ('greenland', 'kommuneqarfik sermersooq', 501, 4)
# ('greenland', 'royal arctic line a/s', 413, 5)
# ('grenada', "st. george's university, grenada", 1198, 1)
# ('grenada', 'true blue bay resort and villas, grenada, west indies', 29, 2)
# ('grenada', 'grenada electricity services limited', 9, 3)
# ('grenada', 'laluna resort', 5, 4)
# ('grenada', 'grenada ports authority', 3, 5)
# ('guadeloupe', 'air caraibes', 480, 1)
# ('guadeloupe', 'air antilles', 111, 2)
# ('guadeloupe', 'la creole beach hotel & spa', 58, 3)
# ('guadeloupe', 'chu de pointe-à-pitre abymes - guadeloupe', 57, 4)
# ('guadeloupe', 'nouvelles iles', 57, 5)
# ('guam', 'university of guam', 755, 1)
# ('guam', 'kuam', 74, 2)
# ('guam', 'sorensen media group', 63, 3)
# ('guam', 'uog endowment foundation', 51, 4)
# ('guam', "today's realty", 41, 5)
# ('guatemala', 'universidad de san carlos de guatemala', 1901, 1)
# ('guatemala', 'telus international central america', 1396, 2)
# ('guatemala', 'universidad rafael landivar', 1377, 3)
# ('guatemala', 'cbc (the central america bottling corporation)', 1272, 4)
# ('guatemala', 'universidad del valle de guatemala', 936, 5)
# ('guernsey', 'trafalgar travel', 883, 1)
# ('guernsey', 'states of guernsey', 753, 2)
# ('guernsey', 'new century', 223, 3)
# ('guernsey', 'healthspan', 222, 4)
# ('guernsey', 'collas crill', 198, 5)
# ('guinea', 'mtn guinea', 386, 1)
# ('guinea', 'orange mali', 360, 2)
# ('guinea', 'compagnie des bauxites de guinée', 149, 3)
# ('guinea', 'eti sa', 107, 4)
# ('guinea', 'mouna group technology sa', 36, 5)
# ('guinea-bissau', 'mtn guinea bissau', 89, 1)
# ('guinea-bissau', 'gome home appliance co. ltd.', 26, 2)
# ('guinea-bissau', 'sino-american shanghai squibb pharmaceutical ltd.', 10, 3)
# ('guinea-bissau', 'escuela bilingüe bambinos aim', 7, 4)
# ('guinea-bissau', 'cosco bulk carrier co., ltd.', 5, 5)
# ('guyana', 'caricom secretariat', 338, 1)
# ('guyana', 'texila american university', 243, 2)
# ('guyana', 'guyana power & light inc.', 178, 3)
# ('guyana', 'gt&t', 151, 4)
# ('guyana', 'clear connect inc.', 89, 5)
# ('haiti', 'hopital albert schweitzer haiti', 93, 1)
# ('haiti', 'cordaid haiti', 78, 2)
# ('haiti', 'meds & food for kids', 70, 3)
# ('haiti', 'healing hands for haiti international inc.', 43, 4)
# ('haiti', 'royal decameron indigo beach resort & spa', 39, 5)
# ('honduras', 'grupo financiero ficohsa', 1417, 1)
# ('honduras', 'unitec', 1282, 2)
# ('honduras', 'banco centroamericano de integración económica (bcie)', 588, 3)
# ('honduras', 'grupo terra', 452, 4)
# ('honduras', 'banco central de honduras', 338, 5)
# ('hong kong', 'shangri-la hotels and resorts', 20102, 1)
# ('hong kong', 'aia', 15368, 2)
# ('hong kong', 'mandarin oriental hotel group', 12606, 3)
# ('hong kong', 'king & wood mallesons', 9082, 4)
# ('hong kong', 'li & fung limited', 7991, 5)
# ('hungary', 'magyar telekom', 4519, 1)
# ('hungary', 'otp bank', 4495, 2)
# ('hungary', 'mol group', 4038, 3)
# ('hungary', 'budapest university of technology and economics', 3188, 4)
# ('hungary', 'it services hungary kft.', 3114, 5)
# ('iceland', 'university of iceland', 2555, 1)
# ('iceland', 'marel', 2484, 2)
# ('iceland', 'össur', 1561, 3)
# ('iceland', 'icelandair', 1285, 4)
# ('iceland', 'ccp', 1253, 5)
# ('india', 'tata consultancy services', 341369, 1)
# ('india', 'infosys', 215718, 2)
# ('india', 'wipro technologies', 177368, 3)
# ('india', 'hcl technologies', 127468, 4)
# ('india', 'tech mahindra', 81583, 5)
# ('indonesia', 'pt bank mandiri (persero) tbk.', 15124, 1)
# ('indonesia', 'bank danamon indonesia', 9603, 2)
# ('indonesia', 'pt. bank negara indonesia (persero) tbk.', 8566, 3)
# ('indonesia', 'pt.pertamina (persero)', 8237, 4)
# ('indonesia', 'telkomsel', 7733, 5)
# ('iran', 'university of tehran', 7466, 1)
# ('iran', 'islamic azad university (iau)- دانشگاه آزاد اسلامی', 5972, 2)
# ('iran', 'sharif university of technology', 4025, 3)
# ('iran', 'mapna group', 3429, 4)
# ('iran', 'tehran university of medical sciences (tums)', 2239, 5)
# ('iraq', 'zain iraq', 1244, 1)
# ('iraq', 'korek telecom', 1146, 2)
# ('iraq', 'ministry of environment', 840, 3)
# ('iraq', 'salahaddin university-erbil', 640, 4)
# ('iraq', 'kurdistan regional government', 490, 5)
# ('ireland', 'accenture', 455768, 1)
# ('ireland', 'covidien', 23405, 2)
# ('ireland', 'allergan', 22949, 3)
# ('ireland', 'ingersoll rand', 19427, 4)
# ('ireland', 'primark stores limited', 18641, 5)
# ('isle of man', 'pokerstars', 1529, 1)
# ('isle of man', 'cibc firstcaribbean international bank', 1245, 2)
# ('isle of man', 'firstcaribbean international bank', 809, 3)
# ('isle of man', 'sbtech', 623, 4)
# ('isle of man', 'the stars group', 591, 5)
# ('israel', 'ness technologies', 11235, 1)
# ('israel', 'tel aviv university', 7358, 2)
# ('israel', 'technion - israel institute of technology', 6574, 3)
# ('israel', 'elbit systems ltd', 6299, 4)
# ('israel', 'the hebrew university of jerusalem', 5604, 5)
# ('italy', 'saipem', 33895, 1)
# ('italy', 'unicredit', 25727, 2)
# ('italy', 'eni', 25036, 3)
# ('italy', 'leonardo', 23304, 4)
# ('italy', 'telecom italia', 22587, 5)
# ('jamaica', 'digicel group', 7931, 1)
# ('jamaica', 'sandals resorts', 3904, 2)
# ('jamaica', 'university of the west indies', 3737, 3)
# ('jamaica', 'national commercial bank jamaica limited', 1471, 4)
# ('jamaica', 'jamaica public service company ltd', 1059, 5)
# ('japan', 'sony', 41048, 1)
# ('japan', 'nissan motor corporation', 36526, 2)
# ('japan', 'toyota', 30119, 3)
# ('japan', 'nomura', 22667, 4)
# ('japan', 'takeda pharmaceuticals', 18142, 5)
# ('jersey', 'cpa global', 2900, 1)
# ('jersey', 'states of jersey', 1500, 2)
# ('jersey', 'ogier', 1152, 3)
# ('jersey', 'petra diamonds', 659, 4)
# ('jersey', 'sanne', 608, 5)
# ('jordan', 'arab bank', 7081, 1)
# ('jordan', 'royal jordanian', 3095, 2)
# ('jordan', 'tesco', 2860, 3)
# ('jordan', 'jordan university of science and technology', 2637, 4)
# ('jordan', 'orange jordan', 2103, 5)
# ('kazakhstan', 'tengizchevroil', 4784, 1)
# ('kazakhstan', 'air astana', 1355, 2)
# ('kazakhstan', 'nazarbayev university', 1192, 3)
# ('kazakhstan', 'ersai caspian contractor llc', 1006, 4)
# ('kazakhstan', 'kcell ао', 928, 5)
# ('kenya', 'safaricom', 5234, 1)
# ('kenya', 'unep', 4092, 2)
# ('kenya', 'kcb bank group', 3362, 3)
# ('kenya', 'university of nairobi', 2893, 4)
# ('kenya', 'co-operative bank of kenya', 2340, 5)
# ('kiribati', 'computron', 157, 1)
# ('kiribati', 'ministry of fisheries and marine resources development', 121, 2)
# ('kiribati', 'tijssen cs - accountants & adviseurs', 31, 3)
# ('kiribati', 'theunissen technical trading b.v.', 28, 4)
# ('kiribati', 'medical training malden', 20, 5)
# ('kosovo', 'protec', 117, 1)
# ('kosovo', 'rrota creative studio', 69, 2)
# ('kosovo', 'kep trust', 61, 3)
# ('kosovo', 'international business college mitrovica', 56, 4)
# ('kosovo', 'administrimi kosovar dhe mirёmbajtja e ndёrtesave – merkur sh.p.k.', 55, 5)
# ('kuwait', 'm. h. alshaya co.', 12010, 1)
# ('kuwait', 'zain', 6557, 2)
# ('kuwait', 'kuwait oil company', 5673, 3)
# ('kuwait', 'national bank of kuwait', 4005, 4)
# ('kuwait', 'keo international consultants', 3527, 5)
# ('kyrgyzstan', 'unicreditbank', 417, 1)
# ('kyrgyzstan', 'american university of central asia', 409, 2)
# ('kyrgyzstan', 'university of central asia', 296, 3)
# ('kyrgyzstan', 'demir kyrgyz international bank', 213, 4)
# ('kyrgyzstan', 'cjsc kyrgyz investment and credit bank', 136, 5)
# ('laos', 'mekong river commission secretariat', 259, 1)
# ('laos', 'ntpc - nam theun 2 power company', 232, 2)
# ('laos', 'kdc', 185, 3)
# ('laos', 'lao telecom company ltd.', 146, 4)
# ('laos', 'tax department, ministry of finance', 146, 5)
# ('latvia', "''skonto buve'' sia", 1886, 1)
# ('latvia', 'lattelecom', 1654, 2)
# ('latvia', 'university of latvia', 1283, 3)
# ('latvia', '4finance', 1201, 4)
# ('latvia', 'rimi baltic group', 1044, 5)
# ('lebanon', 'dar al-handasah (shair and partners)', 9180, 1)
# ('lebanon', 'american university of beirut', 7115, 2)
# ('lebanon', 'azadea group', 5263, 3)
# ('lebanon', 'bank audi', 4633, 4)
# ('lebanon', 'khatib & alami cec', 3574, 5)
# ('lesotho', 'econet telecom lesotho', 368, 1)
# ('lesotho', 'central bank of lesotho', 209, 2)
# ('lesotho', 'lesotho college of education', 117, 3)
# ('lesotho', 'standard lesotho bank limited', 98, 4)
# ('lesotho', 'computer business solutions', 60, 5)
# ('liberia', 'golden veroleum liberia', 194, 1)
# ('liberia', 'lonestar cell/mtn liberia', 194, 2)
# ('liberia', 'cellcom telecommunications', 93, 3)
# ('liberia', 'liberia petroleum refining company (lprc)', 87, 4)
# ('liberia', 'national oil company of liberia', 47, 5)
# ('libya', 'harouge oil operations', 435, 1)
# ('libya', 'libya telecom and technology', 361, 2)
# ('libya', 'arabian gulf oil company (agoco)', 347, 3)
# ('libya', 'libyana mobile phone', 342, 4)
# ('libya', 'mcit', 274, 5)
# ('liechtenstein', 'hilti', 16013, 1)
# ('liechtenstein', 'thyssenkrupp presta ag', 1637, 2)
# ('liechtenstein', 'ivoclar vivadent ag', 1392, 3)
# ('liechtenstein', 'autoscout24', 848, 4)
# ('liechtenstein', 'lgt', 764, 5)
# ('lithuania', 'vilnius university', 1990, 1)
# ('lithuania', 'kaunas university of technology', 1382, 2)
# ('lithuania', 'teo lt, ab', 1320, 3)
# ('lithuania', 'omnitel', 1143, 4)
# ('lithuania', 'seb lietuvoje', 1121, 5)
# ('luxembourg', 'regus', 16176, 1)
# ('luxembourg', 'oriflame', 12744, 2)
# ('luxembourg', 'propia', 8805, 3)
# ('luxembourg', 'eurofins', 6842, 4)
# ('luxembourg', 'altisource', 5330, 5)
# ('macau', 'the venetian® macao-resort-hotel', 2599, 1)
# ('macau', 'galaxy macau', 1112, 2)
# ('macau', 'university of saint joseph', 895, 3)
# ('macau', 'university of macau', 884, 4)
# ('macau', 'city of dreams macau', 702, 5)
# ('macedonia', 'makedonski telekom ad', 929, 1)
# ('macedonia', 'stopanska banka ad - skopje', 754, 2)
# ('macedonia', 'nlb tutunska banka', 629, 3)
# ('macedonia', 'komercijalna banka ad', 531, 4)
# ('macedonia', 'adria airways', 492, 5)
# ('madagascar', 'ambatovy', 1351, 1)
# ('madagascar', 'dts', 465, 2)
# ('madagascar', 'airtel madagascar', 318, 3)
# ('madagascar', 'brasseries star madagascar', 257, 4)
# ('madagascar', 'institut pasteur de madagascar', 186, 5)
# ('malawi', 'telekom networks malawi limited', 469, 1)
# ('malawi', 'opportunity international bank of malawi', 448, 2)
# ('malawi', 'university of malawi, college of medicine', 315, 3)
# ('malawi', 'malawi polytechnic', 166, 4)
# ('malawi', 'nico life insurance company limited', 144, 5)
# ('malaysia', 'petronas', 17359, 1)
# ('malaysia', 'maybank', 10475, 2)
# ('malaysia', "sinsilog's network and marketing", 8852, 3)
# ('malaysia', 'cimb', 7351, 4)
# ('malaysia', 'malaysia airlines', 7131, 5)
# ('maldives', 'dhiraagu', 440, 1)
# ('maldives', 'maldives police service', 321, 2)
# ('maldives', 'bank of maldives plc', 262, 3)
# ('maldives', 'kuramathi island resort', 227, 4)
# ('maldives', 'bandos island resort - maldives', 213, 5)
# ('mali', 'sotelma', 206, 1)
# ('mali', 'azalaï hotels', 126, 2)
# ('mali', 'myagro', 100, 3)
# ('mali', 'cira sa', 82, 4)
# ('mali', 'bureau du vérificateur général', 42, 5)
# ('malta', 'betsson group', 2161, 1)
# ('malta', 'ec', 1821, 2)
# ('malta', 'kindred group plc', 1714, 3)
# ('malta', 'maitland', 1243, 4)
# ('malta', 'air malta', 808, 5)
# ('marshall islands', 'college of the marshall islands', 204, 1)
# ('marshall islands', 'liteforex official', 75, 2)
# ('marshall islands', 'payless supermarket', 27, 3)
# ('marshall islands', 'imperial options', 26, 4)
# ('marshall islands', 'orphy telecom', 19, 5)
# ('martinique', 'tv cable', 568, 1)
# ('martinique', 'air caraibes atlantique', 90, 2)
# ('martinique', 'région martinique', 66, 3)
# ('martinique', 'infodom', 54, 4)
# ('martinique', 'guez caraibes', 51, 5)
# ('mauritania', 'banque centrale de mauritanie', 139, 1)
# ('mauritania', 'tasiast mauritanie ltd sa', 126, 2)
# ('mauritania', 'banque islamique de mauritanie', 29, 3)
# ('mauritania', "anac mauritania's national civil aviation agency", 25, 4)
# ('mauritania', 'asmlgroup', 19, 5)
# ('mauritius', 'air mauritius', 1817, 1)
# ('mauritius', 'mauritius telecom', 1110, 2)
# ('mauritius', 'the mauritius commercial bank ltd', 993, 3)
# ('mauritius', 'lux* resorts & hotels', 863, 4)
# ('mauritius', 'liquid telecom', 774, 5)
# ('mayotte', 'edm (electricite de mayotte)', 97, 1)
# ('mayotte', 'centre universitaire de formation et de recherche de mayotte', 23, 2)
# ('mayotte', 'luvi ogilvy mayotte', 22, 3)
# ('mayotte', 'agence bao [bouche à oreille]', 8, 4)
# ('mayotte', 'cdr de mayotte', 8, 5)
# ('mexico', 'coca-cola femsa', 25552, 1)
# ('mexico', 'pemex', 24617, 2)
# ('mexico', 'cemex', 22190, 3)
# ('mexico', 'imss', 18612, 4)
# ('mexico', 'tecnológico de monterrey', 17094, 5)
# ('micronesia', 'college of micronesia', 626, 1)
# ('micronesia', 'vital energy micronesia', 32, 2)
# ('micronesia', 'fsm statistics', 6, 3)
# ('micronesia', 'nanofabrica', 2, 4)
# ('micronesia', 'fsm development bank', 2, 5)
# ('moldova', 'orange moldova', 716, 1)
# ('moldova', 'moldcell', 505, 2)
# ('moldova', 'adalet consulting srl', 417, 3)
# ('moldova', 'bc mobiasbanca - groupe societe generale sa', 412, 4)
# ('moldova', 'national bank of moldova', 248, 5)
# ('monaco', 'mecaplast group', 2363, 1)
# ('monaco', 'silversea cruises', 2098, 2)
# ('monaco', 'monte-carlo sbm / société des bains de mer', 1491, 3)
# ('monaco', 'hotel metropole monte-carlo', 548, 4)
# ('monaco', 'monaco telecom', 497, 5)
# ('mongolia', 'oyu tolgoi llc / оюу толгой ххк', 810, 1)
# ('mongolia', 'mobicom corporation llc', 558, 2)
# ('mongolia', 'oyu tolgoi llc / оюу толгой ххк', 425, 3)
# ('mongolia', 'unitel llc, mongolia', 359, 4)
# ('mongolia', 'xacbank', 341, 5)
# ('montenegro', 'crnogorski telekom', 348, 1)
# ('montenegro', 'university of montenegro', 326, 2)
# ('montenegro', 'porto montenegro', 276, 3)
# ('montenegro', 'montenegro airlines', 164, 4)
# ('montenegro', 'wall street international', 141, 5)
# ('montserrat', 'government of montserrat', 143, 1)
# ('montserrat', 'university of science, arts & technology', 4, 2)
# ('montserrat', 'the abella group llc', 2, 3)
# ('morocco', 'ocp sa', 10003, 1)
# ('morocco', 'attijariwafa bank', 5582, 2)
# ('morocco', 'bmce bank', 4251, 3)
# ('morocco', 'royal air maroc', 4138, 4)
# ('morocco', 'maroc telecom', 3944, 5)
# ('mozambique', 'vodacom mozambique', 927, 1)
# ('mozambique', 'mcel', 747, 2)
# ('mozambique', 'barclays bank mozambique', 555, 3)
# ('mozambique', 'bci - banco comercial e de investimentos (moçambique/mozambique)', 480, 4)
# ('mozambique', 'millennium bim', 224, 5)
# ('myanmar', 'ooredoo myanmar', 955, 1)
# ('myanmar', 'kbz bank', 520, 2)
# ('myanmar', 'aya bank', 312, 3)
# ('myanmar', 'cb bank (co-operative bank ltd.)', 298, 4)
# ('myanmar', 'myanmar airways international company limited', 287, 5)
# ('namibia', 'university of namibia', 1030, 1)
# ('namibia', 'polytechnic of namibia', 924, 2)
# ('namibia', 'fnb namibia', 794, 3)
# ('namibia', 'ministry of health and social services', 399, 4)
# ('namibia', 'namibia breweries ltd', 369, 5)
# ('nepal', 'nepal telecom', 1092, 1)
# ('nepal', 'cloudfactory.', 863, 2)
# ('nepal', 'kathmandu university', 663, 3)
# ('nepal', 'chaudhary group', 648, 4)
# ('nepal', 'worldlink', 429, 5)
# ('netherlands', 'shell', 147906, 1)
# ('netherlands', 'abn amro bank n.v.', 82764, 2)
# ('netherlands', 'randstad', 56544, 3)
# ('netherlands', 'aiesec', 47772, 4)
# ('netherlands', 'kpn', 47611, 5)
# ('netherlands antilles', 'refineria i.s.l.a. curacao', 292, 1)
# ('netherlands antilles', 'saba university school of medicine', 155, 2)
# ('netherlands antilles', 'guardian group dutch caribbean', 140, 3)
# ('netherlands antilles', 'deloitte dutch caribbean', 138, 4)
# ('netherlands antilles', 'hbn law', 121, 5)
# ('new caledonia', 'koniambo nickel sas', 821, 1)
# ('new caledonia', 'société le nickel - sln - eramet', 566, 2)
# ('new caledonia', 'gouvernement de la nouvelle-calédonie', 531, 3)
# ('new caledonia', 'province sud', 281, 4)
# ('new caledonia', 'opt nouvelle-calédonie', 278, 5)
# ('new zealand', 'suncorp group', 16078, 1)
# ('new zealand', 'fonterra', 14466, 2)
# ('new zealand', 'the university of auckland', 13977, 3)
# ('new zealand', 'spark new zealand', 10376, 4)
# ('new zealand', 'air new zealand', 8347, 5)
# ('nicaragua', 'claro nicaragua', 723, 1)
# ('nicaragua', 'grupo lafise', 602, 2)
# ('nicaragua', 'banpro nicaragua', 437, 3)
# ('nicaragua', 'bufete de abogados', 391, 4)
# ('nicaragua', 'universidad americana (uam)', 340, 5)
# ('niger', 'airtel niger', 275, 1)
# ('niger', 'imouraren s.a.', 36, 2)
# ('niger', 'sahelcom sa', 29, 3)
# ('niger', 'proxymeo crm', 19, 4)
# ('niger', 'liptinfor niger', 8, 5)
# ('nigeria', 'uba group', 7336, 1)
# ('nigeria', 'access bank plc', 6388, 2)
# ('nigeria', 'diamond bank plc', 5358, 3)
# ('nigeria', 'mtn nigeria', 4479, 4)
# ('nigeria', 'gtbank', 4435, 5)
# ('niue', 'rocket systems ltd', 2, 1)
# ('norfolk island', 'norfolk blue restaurant grill & bar', 3, 1)
# ('north korea', 'pyongyang university of science & technology (pust)', 19, 1)
# ('north korea', 'isn network company limited', 9, 2)
# ('north korea', 'plastoform industries ltd', 6, 3)
# ('north korea', 'beacon point ltd', 2, 4)
# ('north korea', 'korea national insurance corporation', 1, 5)
# ('northern mariana islands', 'tinian dynasty hotel & casino', 73, 1)
# ('northern mariana islands', 'star marianas air, inc', 65, 2)
# ('northern mariana islands', 'bridge capital, llc', 50, 3)
# ('northern mariana islands', 'micronesian legal services corporation', 36, 4)
# ('northern mariana islands', 'sherman consulting, llc', 13, 5)
# ('norway', 'telenor', 33441, 1)
# ('norway', 'aker solutions', 27587, 2)
# ('norway', 'statoil', 25061, 3)
# ('norway', 'dnv gl', 14269, 4)
# ('norway', 'ntnu', 13019, 5)
# ('oman', 'petroleum development oman', 8525, 1)
# ('oman', 'galfar engineering & contracting saog', 3088, 2)
# ('oman', 'oman air', 2637, 3)
# ('oman', 'omantel', 1755, 4)
# ('oman', 'bank muscat', 1747, 5)
# ('pakistan', 'ptcl', 12902, 1)
# ('pakistan', 'mobilink', 11812, 2)
# ('pakistan', 'bank alfalah limited', 8628, 3)
# ('pakistan', 'mcb bank limited', 8520, 4)
# ('pakistan', 'descon engineering limited', 8327, 5)
# ('palau', 'surangel and sons co', 45, 1)
# ('palau', 'palau royal resort - nikko hotel international', 37, 2)
# ('palau', 'fish n fins', 6, 3)
# ('palau', 'palau dive adventures', 4, 4)
# ('palau', 'pacific renewables, inc.', 4, 5)
# ('palestine', 'unrwa', 2832, 1)
# ('palestine', 'birzeit university', 1278, 2)
# ('palestine', 'paltel', 816, 3)
# ('palestine', 'bci', 674, 4)
# ('palestine', 'bank of palestine', 354, 5)
# ('panama', 'bac|credomatic', 4876, 1)
# ('panama', 'copa airlines', 4539, 2)
# ('panama', 'banco general', 1483, 3)
# ('panama', 'universidad tecnológica de panamá', 1448, 4)
# ('panama', 'cable & wireless panama', 1446, 5)
# ('papua new guinea', 'oil search limited', 2089, 1)
# ('papua new guinea', 'ok tedi mining limited', 1831, 2)
# ('papua new guinea', 'pricewaterhousecoopers limited', 1741, 3)
# ('papua new guinea', 'bank of south pacific', 1362, 4)
# ('papua new guinea', 'air niugini', 1015, 5)
# ('paraguay', 'web design', 501, 1)
# ('paraguay', 'universidad americana - paraguay', 305, 2)
# ('paraguay', 'banco continental saeca', 295, 3)
# ('paraguay', 'personal paraguay', 283, 4)
# ('paraguay', 'parque tecnológico itaipu', 277, 5)
# ('peru', 'banco de crédito bcp', 16155, 1)
# ('peru', 'belcorp', 8899, 2)
# ('peru', 'interbank', 8635, 3)
# ('peru', 'pontificia universidad católica del peru - pucp', 7576, 4)
# ('peru', 'ministerio de educación del perú - minedu', 6647, 5)
# ('philippines', 'smart communications, inc.', 8998, 1)
# ('philippines', 'department of education - philippines', 8832, 2)
# ('philippines', 'pldt', 7428, 3)
# ('philippines', 'abs-cbn', 7341, 4)
# ('philippines', 'asian development bank', 6139, 5)
# ('poland', 'orange polska', 7396, 1)
# ('poland', 'comarch', 6117, 2)
# ('poland', 'pko bank polski', 5176, 3)
# ('poland', 'pzu', 4778, 4)
# ('poland', 'att', 4532, 5)
# ('portugal', 'portugal telecom', 7689, 1)
# ('portugal', 'edp', 5433, 2)
# ('portugal', 'sonae', 4927, 3)
# ('portugal', 'millennium bcp', 4875, 4)
# ('portugal', 'instituto superior técnico', 4793, 5)
# ('puerto rico', 'europcar', 9097, 1)
# ('puerto rico', 'banco popular de puerto rico', 3502, 2)
# ('puerto rico', 'sartorius', 1699, 3)
# ('puerto rico', 'university of puerto rico, río piedras', 1082, 4)
# ('puerto rico', 'evertec', 1073, 5)
# ('qatar', 'qatar airways', 19062, 1)
# ('qatar', 'qatar petroleum', 8843, 2)
# ('qatar', 'hamad medical corporation', 7096, 3)
# ('qatar', 'al jazeera media network', 4972, 4)
# ('qatar', 'qnb group', 3646, 5)
# ('republic of the congo', 'skytic telecom', 3, 1)
# ('republic of the congo', 'petroleum trading congo e&p sa', 2, 2)
# ('republic of the congo', 'somedia', 2, 3)
# ('republic of the congo', 'its congo', 2, 4)
# ('romania', 'bcr', 7052, 1)
# ('romania', 'telekom romania', 5831, 2)
# ('romania', 'brd', 5384, 3)
# ('romania', 'omv petrom', 5253, 4)
# ('romania', 'cora', 4621, 5)
# ('russia', 'yandex', 8137, 1)
# ('russia', 'mts group', 7204, 2)
# ('russia', 'sberbank', 6863, 3)
# ('russia', 'lukoil', 6201, 4)
# ('russia', 'alfa-bank', 4865, 5)
# ('rwanda', 'mtn rwanda', 595, 1)
# ('rwanda', 'university of rwanda', 455, 2)
# ('rwanda', 'rwandair ltd', 430, 3)
# ('rwanda', 'bank of kigali limited', 235, 4)
# ('rwanda', 'akilah institute for women', 138, 5)
# ('réunion', 'université de la réunion', 740, 1)
# ('réunion', 'sfr reunion', 293, 2)
# ('réunion', 'facto-saatchi&saatchi', 82, 3)
# ('réunion', 'stor solutions', 82, 4)
# ('réunion', 'redis', 63, 5)
# ('saint barthélemy', 'emmanuel jacques almosnino law firm', 3, 1)
# ('saint helena', 'enterprise st helena', 18, 1)
# ('saint kitts and nevis', 'eastern caribbean central bank', 215, 1)
# ('saint kitts and nevis', 'brickcom corporation', 72, 2)
# ('saint kitts and nevis', 'converge solutions inc.', 24, 3)
# ('saint kitts and nevis', 'yu lounge', 24, 4)
# ('saint kitts and nevis', 'development bank of st. kitts & nevis', 9, 5)
# ('saint lucia', 'waste connections, inc.', 1782, 1)
# ('saint lucia', 'public authority for applied education and training, paaet', 348, 2)
# ('saint lucia', 'oecs', 105, 3)
# ('saint lucia', 'statetrust bank', 97, 4)
# ('saint lucia', 'bay gardens resorts', 71, 5)
# ('saint martin', 'dauphin telecom', 4, 1)
# ('saint martin', 'exofor-exogroup', 2, 2)
# ('saint martin', 'goldfinger jewelry - bijouteries', 2, 3)
# ('saint martin', 'changeway', 1, 4)
# ('saint martin', 'pirate web studio', 1, 5)
# ('saint pierre and miquelon', 'auto action', 1, 1)
# ('saint vincent and the grenadines', 'the university of the west indies-open campus', 185, 1)
# ('saint vincent and the grenadines', 'loyal bank limited', 78, 2)
# ('saint vincent and the grenadines', 'profis ltd.', 36, 3)
# ('saint vincent and the grenadines', 'euro pacific bank ltd.', 32, 4)
# ('saint vincent and the grenadines', 'richmond vale academy', 30, 5)
# ('samoa', 'spbd microfinance network', 50, 1)
# ('samoa', 'samoa water authority', 38, 2)
# ('samoa', 'i.h carruthers ltd', 17, 3)
# ('samoa', 'samoa stationery & books ltd', 16, 4)
# ('samoa', 'samoa tourism authority', 16, 5)
# ('san marino', 'colombini s.a.', 215, 1)
# ('san marino', 'erba vita', 80, 2)
# ('san marino', 'promopharma', 73, 3)
# ('san marino', 'titanka! spa', 64, 4)
# ('san marino', 'san marino rtv', 54, 5)
# ('saudi arabia', 'saudi aramco', 40870, 1)
# ('saudi arabia', 'sabic', 28606, 2)
# ('saudi arabia', 'saudi telecom company', 12951, 3)
# ('saudi arabia', 'saudi electricity company', 8498, 4)
# ('saudi arabia', 'saudi arabian airlines', 8249, 5)
# ('senegal', 'sonatel', 2099, 1)
# ('senegal', 'bank of africa', 1433, 2)
# ('senegal', "ministère de l'enseignement supérieur", 1067, 3)
# ('senegal', 'virgin nigeria airways', 510, 4)
# ('senegal', 'port autonome de dakar sénégal', 367, 5)
# ('serbia', 'nis gazprom neft', 3025, 1)
# ('serbia', 'telekom srbija', 2136, 2)
# ('serbia', 'vip mobile d.o.o.', 1305, 3)
# ('serbia', 'nbs', 1174, 4)
# ('serbia', 'air serbia', 1138, 5)
# ('seychelles', 'fregate island private', 146, 1)
# ('seychelles', 'savoy resort & spa seychelles', 106, 2)
# ('seychelles', 'public utilities corporation', 96, 3)
# ('seychelles', 'desroches island', 85, 4)
# ('seychelles', 'tickmill', 79, 5)
# ('sierra leone', 'sierra rutile limited', 348, 1)
# ('sierra leone', 'st john of god hospital', 306, 2)
# ('sierra leone', 'fourah bay college - university of sierra leone', 152, 3)
# ('sierra leone', 'union trust bank ltd', 56, 4)
# ('sierra leone', 'kpmg sierra leone', 48, 5)
# ('singapore', 'flextronics', 46941, 1)
# ('singapore', 'dbs bank', 20371, 2)
# ('singapore', 'national university of singapore', 16399, 3)
# ('singapore', 'ocbc bank', 12348, 4)
# ('singapore', 'united overseas bank limited (uob)', 12283, 5)
# ('sint maarten', 'lexwell', 26, 1)
# ('sint maarten', 'cecc n.v.', 19, 2)
# ('sint maarten', 'notary office sps', 13, 3)
# ('sint maarten', 'front street pharmacy sint maarten', 2, 4)
# ('sint maarten', 'altus n.v.', 1, 5)
# ('slovakia', 'slovak telekom', 2450, 1)
# ('slovakia', 'tatra banka', 2323, 2)
# ('slovakia', 'vúb banka', 1921, 3)
# ('slovakia', 'slovenská sporiteľňa', 1518, 4)
# ('slovakia', 'fleming gulf', 1480, 5)
# ('slovenia', 'krka', 2948, 1)
# ('slovenia', 'municipality', 1478, 2)
# ('slovenia', 'university of ljubljana', 1273, 3)
# ('slovenia', 'nil ltd.', 1199, 4)
# ('slovenia', 'nlb d.d.', 1131, 5)
# ('solomon islands', 'solomon islands electricity authority', 38, 1)
# ('solomon islands', 'ministry of foreign affairs and external trade', 20, 2)
# ('solomon islands', 'pan oceanic bank', 12, 3)
# ('solomon islands', 'solomon breweries limited', 11, 4)
# ('solomon islands', 'pacific horizons consultancy group ltd', 9, 5)
# ('somalia', 'sparebanken hedmark', 428, 1)
# ('somalia', 'somtel international ltd', 257, 2)
# ('somalia', 'golis telecom somalia', 132, 3)
# ('somalia', 'simad university', 107, 4)
# ('somalia', 'somcable ltd.', 79, 5)
# ('south africa', 'standard bank group', 37478, 1)
# ('south africa', 'absa', 26999, 2)
# ('south africa', 'dimension data', 25551, 3)
# ('south africa', 'nedbank', 23393, 4)
# ('south africa', 'fnb south africa', 17889, 5)
# ('south korea', 'lg electronics', 47846, 1)
# ('south korea', 'hyundai engineering & construction co.,ltd.', 7626, 2)
# ('south korea', 'samsung engineering', 6885, 3)
# ('south korea', 'samsung sds', 6427, 4)
# ('south korea', 'gs e&c', 5643, 5)
# ('south sudan', 'forcier consulting', 257, 1)
# ('south sudan', 'dar petroleum operating company ltd.', 237, 2)
# ('south sudan', 'nile petroleum service co.ltd', 14, 3)
# ('south sudan', 'hold the child', 14, 4)
# ('south sudan', 'zain south sudan', 13, 5)
# ('spain', 'banco santander', 84270, 1)
# ('spain', 'telefónica', 76432, 2)
# ('spain', 'inditex', 45690, 3)
# ('spain', 'indra', 42025, 4)
# ('spain', 'bbva', 37671, 5)
# ('sri lanka', 'mas holdings', 5284, 1)
# ('sri lanka', 'dialog axiata plc', 4401, 2)
# ('sri lanka', 'brandix', 2556, 3)
# ('sri lanka', 'university of moratuwa', 2076, 4)
# ('sri lanka', 'university of peradeniya', 1929, 5)
# ('sudan', 'university of khartoum', 1064, 1)
# ('sudan', 'zain sudan', 1011, 2)
# ('sudan', 'sudatel telecom group, ltd', 779, 3)
# ('sudan', 'sayga flour mills', 510, 4)
# ('sudan', 'canar telecom', 399, 5)
# ('suriname', 'staatsolie maatschappij suriname n.v', 691, 1)
# ('suriname', 'telesur', 618, 2)
# ('suriname', 'anton de kom university', 148, 3)
# ('suriname', 'the torarica group of hotels', 137, 4)
# ('suriname', 'hakrinbank n.v.', 108, 5)
# ('svalbard and jan mayen', 'the university centre in svalbard (unis)', 146, 1)
# ('svalbard and jan mayen', 'spitsbergen travel', 128, 2)
# ('svalbard and jan mayen', 'longyearbyen lokalstyre', 35, 3)
# ('svalbard and jan mayen', 'hurtigruten svalbard as', 19, 4)
# ('svalbard and jan mayen', 'aeco (association of arctic expedition cruise operators)', 7, 5)
# ('swaziland', 'swaziland electricity company', 326, 1)
# ('swaziland', 'mtn swaziland', 292, 2)
# ('swaziland', 'inyatsi construction', 232, 3)
# ('swaziland', 'swaziland posts and telecommunications corporation', 203, 4)
# ('swaziland', 'datanet', 101, 5)
# ('sweden', 'ericsson', 178578, 1)
# ('sweden', 'ikea group', 68830, 2)
# ('sweden', 'h&m', 62664, 3)
# ('sweden', 'nordea', 32665, 4)
# ('sweden', 'skanska', 31134, 5)
# ('switzerland', 'nestlé', 139821, 1)
# ('switzerland', 'ubs', 128075, 2)
# ('switzerland', 'novartis', 117021, 3)
# ('switzerland', 'abb', 107903, 4)
# ('switzerland', 'credit suisse', 96595, 5)
# ('syria', 'syriatel', 2339, 1)
# ('syria', 'mtn syria', 1041, 2)
# ('syria', 'abu-ghazaleh& co.consulting/member of talal abu-ghazaleh organization', 667, 3)
# ('syria', 'syrian arab red crescent', 431, 4)
# ('syria', 'banque bemo saudi fransi', 354, 5)
# ('são tomé and príncipe', 'cst - companhia santomense de telecomunicações, sarl', 26, 1)
# ('são tomé and príncipe', 'unitel stp', 12, 2)
# ('são tomé and príncipe', 'andré aureliano aragão & advogados associados', 6, 3)
# ('são tomé and príncipe', 'bananafixe', 2, 4)
# ('são tomé and príncipe', 'the sovereign order of the ecumenical knights of malta o.s.j', 2, 5)
# ('taiwan', 'foxconn', 30421, 1)
# ('taiwan', 'asus', 10352, 2)
# ('taiwan', 'htc', 8601, 3)
# ('taiwan', 'acer', 7671, 4)
# ('taiwan', 'national taiwan university', 6271, 5)
# ('tajikistan', 'cjsc indigo tajikistan', 207, 1)
# ('tajikistan', 'cjsc babilon-mobile', 68, 2)
# ('tajikistan', 'bank eskhata', 44, 3)
# ('tajikistan', 'babilon-t llc', 43, 4)
# ('tajikistan', 'spitamen bank', 42, 5)
# ('tanzania', 'university of dar es salaam (udsm)', 1155, 1)
# ('tanzania', 'crdb bank plc', 906, 2)
# ('tanzania', 'nmb plc', 766, 3)
# ('tanzania', 'sokoine university of agriculture', 750, 4)
# ('tanzania', 'jubilee insurance company ltd', 740, 5)
# ('thailand', 'hang seng bank', 4401, 1)
# ('thailand', 'ascom2', 3816, 2)
# ('thailand', 'scg', 3408, 3)
# ('thailand', 'chulalongkorn university', 3285, 4)
# ('thailand', 'anantara hotels, resorts and spas', 3201, 5)
# ('timor-leste', 'catalpa international', 14, 1)
# ('timor-leste', 'novo turismo resort & spa', 8, 2)
# ('timor-leste', 'halsion lda', 7, 3)
# ('timor-leste', 'pt. cakrawala teknologi informasi', 4, 4)
# ('timor-leste', 'ju,s jurídico social consultoria lda', 4, 5)
# ('togo', 'vert marine', 246, 1)
# ('togo', 'groupe orabank', 170, 2)
# ('togo', 'faculty of sciences', 149, 3)
# ('togo', 'west african development bank', 135, 4)
# ('togo', 'auxitec industrie', 123, 5)
# ('tonga', 'tonga communications corporation', 33, 1)
# ('tonga', 'royco amalgamated company limited', 6, 2)
# ('tonga', 'tonga development bank', 6, 3)
# ('tonga', 'tonga business enterprise centre', 5, 4)
# ('tonga', 'leiola group limited', 2, 5)
# ('trinidad and tobago', 'tstt', 1872, 1)
# ('trinidad and tobago', 'university of trinidad and tobago', 956, 2)
# ('trinidad and tobago', 'atlantic lng', 814, 3)
# ('trinidad and tobago', 'the national gas company of trinidad and tobago limited', 744, 4)
# ('trinidad and tobago', 'costaatt  college of science, technology and applied arts of trinidad and tobago', 510, 5)
# ('tunisia', 'tunisie télécom', 5027, 1)
# ('tunisia', 'african development bank', 3088, 2)
# ('tunisia', 'ooredoo tunisie', 3065, 3)
# ('tunisia', 'tunisair', 2423, 4)
# ('tunisia', 'biat', 1834, 5)
# ('turkey', 'mynet', 22123, 1)
# ('turkey', 'turk telekom', 13923, 2)
# ('turkey', 'turkcell', 13284, 3)
# ('turkey', 'turkish airlines', 12919, 4)
# ('turkey', 'garanti bank', 12069, 5)
# ('turkmenistan', 'eni turkmenistan limited', 94, 1)
# ('turkmenistan', 'ashgabat2017', 67, 2)
# ('turkmenistan', 'merdem hj | catering', 21, 3)
# ('turkmenistan', 'awtoyoly group of companies', 11, 4)
# ('turkmenistan', 'turkmen-tranzit', 10, 5)
# ('turks and caicos islands', 'gansevoort turks & caicos', 65, 1)
# ('turks and caicos islands', 'turks and caicos islands airports authority', 43, 2)
# ('turks and caicos islands', 'misick & stanbrook', 40, 3)
# ('turks and caicos islands', 'veranda resort and residences', 33, 4)
# ('turks and caicos islands', 'devcon ltd', 27, 5)
# ('tuvalu', 'kenson group', 110, 1)
# ('tuvalu', 'roof systems ltd.', 18, 2)
# ('tuvalu', 'langdons language institute', 18, 3)
# ('tuvalu', 'caribbean tech trendz limited (cttl)', 15, 4)
# ('tuvalu', 'international merchandising solutions s.a', 8, 5)
# ('u.s. virgin islands', 'graham communication design group', 1, 1)
# ('uganda', 'makerere university', 2600, 1)
# ('uganda', 'umeme ltd', 1207, 2)
# ('uganda', 'mtn uganda', 1151, 3)
# ('uganda', 'uganda telecom ltd', 958, 4)
# ('uganda', 'vision group', 776, 5)
# ('ukraine', 'ciklum', 5173, 1)
# ('ukraine', 'privatbank', 3680, 2)
# ('ukraine', 'travel agency "fishka"', 2552, 3)
# ('ukraine', 'ukrtelecom', 2550, 4)
# ('ukraine', 'kyivstar gsm', 2295, 5)
# ('united arab emirates', 'emirates', 33168, 1)
# ('united arab emirates', 'etisalat', 17548, 2)
# ('united arab emirates', 'jumeirah group / jumeirah hotels & resorts', 13267, 3)
# ('united arab emirates', 'etihad airways', 12621, 4)
# ('united arab emirates', 'landmark group', 12064, 5)
# ('united kingdom', 'ey', 428960, 1)
# ('united kingdom', 'hsbc', 225649, 2)
# ('united kingdom', 'vodafone', 174892, 3)
# ('united kingdom', 'unilever', 168219, 4)
# ('united kingdom', 'gsk', 147725, 5)
# ('united states', 'ibm', 716906, 1)
# ('united states', 'us army', 445958, 2)
# ('united states', 'hewlett-packard', 412952, 3)
# ('united states', 'pwc', 379447, 4)
# ('united states', 'deloitte', 329145, 5)
# ('uruguay', 'antel', 5252, 1)
# ('uruguay', 'universidad de la república', 2698, 2)
# ('uruguay', 'consejo de educación secundaria', 2370, 3)
# ('uruguay', 'universidad ort uruguay', 2048, 4)
# ('uruguay', 'ute', 2026, 5)
# ('uzbekistan', 'ucell', 402, 1)
# ('uzbekistan', 'unitel llc, uzbekistan.', 282, 2)
# ('uzbekistan', 'westminster international university in tashkent', 242, 3)
# ('uzbekistan', 'ип ооо "teletech"', 210, 4)
# ('uzbekistan', 'halk bank', 158, 5)
# ('vanuatu', 'air vanuatu', 108, 1)
# ('vanuatu', 'iririki island resort & spa port vila', 54, 2)
# ('vanuatu', 'vanuatu national disaster management office', 35, 3)
# ('vanuatu', 'national bank of vanuatu', 9, 4)
# ('vanuatu', 'adventures in paradise', 7, 5)
# ('venezuela', 'pdvsa petroleos de venezuela s.a.', 25620, 1)
# ('venezuela', 'cantv', 7119, 2)
# ('venezuela', 'empresas polar', 5720, 3)
# ('venezuela', 'banesco banco universal', 4990, 4)
# ('venezuela', 'libre ejercicio profesional', 3948, 5)
# ('vietnam', 'fpt software', 4662, 1)
# ('vietnam', 'vng corporation', 1805, 2)
# ('vietnam', 'tma solutions', 1602, 3)
# ('vietnam', 'rmit university vietnam', 1542, 4)
# ('vietnam', 'ila vietnam', 1371, 5)
# ('western sahara', 'king pelagique group', 24, 1)
# ('western sahara', 'groupe abdellaoui', 2, 2)
# ('western sahara', 'king seafood', 2, 3)
# ('yemen', 'taiz university', 215, 1)
# ('yemen', 'yemensoft', 150, 2)
# ('yemen', 'international university of technology twintech', 68, 3)
# ('yemen', 'hs group, llc', 66, 4)
# ('yemen', 'grant thornton yemen', 53, 5)
# ('zambia', 'university of zambia', 1177, 1)
# ('zambia', 'zambia national commercial bank plc', 920, 2)
# ('zambia', 'zambia revenue authority', 890, 3)
# ('zambia', 'mtn zambia', 737, 4)
# ('zambia', 'zambia sugar plc', 462, 5)
# ('zimbabwe', 'jewson', 2687, 1)
# ('zimbabwe', 'econet wireless zimbabwe', 2020, 2)
# ('zimbabwe', 'delta beverages pvt ltd', 1929, 3)
# ('zimbabwe', 'university of zimbabwe', 1706, 4)
# ('zimbabwe', "loughborough students' union", 1166, 5)
# ('Åland islands', 'crosskey banking solutions', 277, 1)
# ('Åland islands', 'ålands landskapsregering', 196, 2)
# ('Åland islands', 'rederiaktiebolaget eckerö', 116, 3)
# ('Åland islands', 'posten åland', 94, 4)
# ('Åland islands', 'åland university of applied sciences', 76, 5)

# %%
cur.execute(f"""
    EXPLAIN QUERY PLAN {query_3}
""")

for c in cur.fetchall():
    print(c)
# Out:
# (2, 0, 0, 'CO-ROUTINE ranks')
# (5, 2, 0, 'CO-ROUTINE (subquery-3)')
# (8, 5, 0, 'SCAN CompanyDataset')
# (21, 5, 0, 'USE TEMP B-TREE FOR ORDER BY')
# (39, 2, 0, 'SCAN (subquery-3)')
# (88, 0, 0, 'SCAN ranks')
# (105, 0, 0, 'USE TEMP B-TREE FOR DISTINCT')
# (106, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')

# %%
cur.execute("""
    CREATE INDEX countries ON CompanyDataset (`country`);
""")

# %%
cur.execute(f"""
    EXPLAIN QUERY PLAN {query_3}
""")

for c in cur.fetchall():
    print(c)
# Out:
# (2, 0, 0, 'CO-ROUTINE ranks')
# (5, 2, 0, 'CO-ROUTINE (subquery-3)')
# (9, 5, 0, 'SCAN CompanyDataset USING INDEX countries')
# (30, 5, 0, 'USE TEMP B-TREE FOR RIGHT PART OF ORDER BY')
# (52, 2, 0, 'SCAN (subquery-3)')
# (101, 0, 0, 'SCAN ranks')
# (118, 0, 0, 'USE TEMP B-TREE FOR DISTINCT')
# (119, 0, 0, 'USE TEMP B-TREE FOR ORDER BY')

# %% [markdown]
# ## Finalize

# %%
cur.close()
con.close()
